# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 KB 17.5 MB/s eta 0:00:00
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 KB 40.8 MB/s eta 0:00:00
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 KB 15.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: plotly in /shared-libs/python3.9/py/lib/python3.9/site-packages (from -r ./requirements.txt (line 4)) (5.10.0)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: numpy>=1.9.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from cufflinks->-r ./requirements.txt (line 3)) (1.23.4)
# Requirement already satisfied: pandas>=0.19.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from cufflinks->-r ./requirements.txt (line 3)) (1.2.5)
# Requirement already satisfied: six>=1.9.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from cufflinks->-r ./requirements.txt (line 3)) (1.16.0)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in /root/venv/lib/python3.9/site-packages (from cufflinks->-r ./requirements.txt (line 3)) (58.1.0)
# Requirement already satisfied: ipython>=5.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from cufflinks->-r ./requirements.txt (line 3)) (8.5.0)
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-8.0.6-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 KB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from plotly->-r ./requirements.txt (line 4)) (8.1.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (3.0.31)
# Requirement already satisfied: traitlets>=5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (5.5.0)
# Requirement already satisfied: stack-data in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (0.17.2)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: decorator in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (2.13.0)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (6.16.1)
# Collecting widgetsnbextension~=4.0.7
#   Downloading widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 65.4 MB/s eta 0:00:00
# Collecting jupyterlab-widgets~=3.0.7
#   Downloading jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.2/198.2 KB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.19.2->cufflinks->-r ./requirements.txt (line 3)) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=0.19.2->cufflinks->-r ./requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: debugpy>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (7.4.3)
# Requirement already satisfied: psutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (5.9.3)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (21.3)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (1.5.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (0.2.5)
# Requirement already satisfied: pure-eval in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: executing in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: asttokens in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=5.3.0->cufflinks->-r ./requirements.txt (line 3)) (2.0.8)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (4.11.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks->-r ./requirements.txt (line 3)) (3.0.9)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (setup.py): started
#   Building wheel for cufflinks (setup.py): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=67917 sha256=183ca66d34f0c4d47e11d578fb96afbf57db6148cf445a51c13bba130fd02293
#   Stored in directory: /root/.cache/pip/wheels/29/b4/f8/2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# Installing collected packages: colorlover, xlrd, widgetsnbextension, jupyterlab-widgets, et-xmlfile, openpyxl, ipywidgets, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3 et-xmlfile-1.1.0 ipywidgets-8.0.6 jupyterlab-widgets-3.0.7 openpyxl-3.1.2 widgetsnbextension-4.0.7 xlrd-2.0.1
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=be64eacb-dd3b-49fa-98fa-58561336328e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
